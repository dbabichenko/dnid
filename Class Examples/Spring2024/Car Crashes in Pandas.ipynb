# %%
# https://www.kaggle.com/datasets/joebeachcapital/car-crashes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('Motor_Vehicle_Collisions_-_Crashes.csv')
df.head()
# Out:
# /var/folders/g5/769syzw563n0bl73j5k78klc0000gn/T/ipykernel_58076/403175560.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Motor_Vehicle_Collisions_-_Crashes.csv')
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# ...

# %%
for item in list(df.columns[:15]):
    print(item)
# Out:
# CRASH_DATE
# CRASH_TIME
# BOROUGH
# ZIP_CODE
# LATITUDE
# LONGITUDE
# LOCATION
# ON_STREET_NAME
# CROSS_STREET_NAME
# OFF_STREET_NAME
# NUMBER_OF_PERSONS_INJURED
# NUMBER_OF_PERSONS_KILLED
# NUMBER_OF_PEDESTRIANS_INJURED
# NUMBER_OF_PEDESTRIANS_KILLED
# NUMBER_OF_CYCLIST_INJURED

# %%
df.head(10)
# Out:
#    CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39        NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45        NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55        NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35   BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13   BROOKLYN  11233.0  40.683304 -73.917274
# 5  04/14/2021      12:47        NaN      NaN        NaN        NaN
# 6  12/14/2021      17:05        NaN      NaN  40.709183 -73.956825
# 7  12/14/2021       8:17      BRONX  10475.0  40.868160 -73.831480
# 8  12/14/2021      21:10   BROOKLYN  11207.0  40.671720 -73.897100
# 9  12/14/2021      14:58  MANHATTAN  10017.0  40.751440 -73.973970
#
#                   LOCATION                ON STREET NAME CROSS STREET NAME  \
# 0                      NaN         WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN       QUEENSBORO BRIDGE UPPER               NaN
# ...

# %%
df.tail()
# Out:
#          CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 2018958  07/03/2023      18:05        NaN      NaN  40.866806 -73.931010
# 2018959  07/22/2023      21:39      BRONX  10457.0  40.844177 -73.902920
# 2018960  07/02/2023      17:55  MANHATTAN  10006.0  40.711033 -74.014540
# 2018961  07/22/2023      13:15     QUEENS  11433.0  40.691580 -73.793190
# 2018962  07/22/2023       3:00     QUEENS  11433.0  40.700240 -73.792854
#
#                        LOCATION   ON STREET NAME CROSS STREET NAME  \
# 2018958  (40.866806, -73.93101)  RIVERSIDE DRIVE               NaN
# 2018959  (40.844177, -73.90292)  EAST 174 STREET    WEBSTER AVENUE
# 2018960  (40.711033, -74.01454)      WEST STREET    LIBERTY STREET
# 2018961   (40.69158, -73.79319)       110 AVENUE        157 STREET
# 2018962  (40.70024, -73.792854)       SOUTH ROAD        164 STREET
#
#         OFF STREET NAME  ...   CONTRIBUTING FACTOR VEHICLE 2  \
# ...

# %%
df.sample(5)
# Out:
#          CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 80858    04/13/2022       7:23       NaN      NaN  40.738070  -73.93756
# 1934456  09/14/2022      16:15  BROOKLYN  11206.0  40.706757  -73.94141
# 1982807  03/09/2023       8:30     BRONX  10451.0        NaN        NaN
# 217155   09/06/2020       5:35       NaN      NaN  40.823647  -73.87843
# 344961   09/27/2019       9:30       NaN      NaN  40.698677  -73.95886
#
#                        LOCATION                    ON STREET NAME  \
# 80858     (40.73807, -73.93756)            LONG ISLAND EXPRESSWAY
# 1934456  (40.706757, -73.94141)                   HUMBOLDT STREET
# 1982807                     NaN                   EXTERIOR STREET
# 217155   (40.823647, -73.87843)  BRUCKNER EXPRESSWAY
# 344961   (40.698677, -73.95886)  FLUSHING AVENUE
#
#         CROSS STREET NAME OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 80858                 NaN             NaN  ...                    Unspecified
# ...

# %%
df.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# ...

# %%
df.shape
# Out:
# (2018963, 29)

# %%
df.dtypes
# Out:
# CRASH DATE                        object
# CRASH TIME                        object
# BOROUGH                           object
# ZIP CODE                          object
# LATITUDE                         float64
# LONGITUDE                        float64
# LOCATION                          object
# ON STREET NAME                    object
# CROSS STREET NAME                 object
# OFF STREET NAME                   object
# NUMBER OF PERSONS INJURED        float64
# NUMBER OF PERSONS KILLED         float64
# NUMBER OF PEDESTRIANS INJURED      int64
# NUMBER OF PEDESTRIANS KILLED       int64
# NUMBER OF CYCLIST INJURED          int64
# NUMBER OF CYCLIST KILLED           int64
# NUMBER OF MOTORIST INJURED         int64
# NUMBER OF MOTORIST KILLED          int64
# CONTRIBUTING FACTOR VEHICLE 1     object
# CONTRIBUTING FACTOR VEHICLE 2     object
# CONTRIBUTING FACTOR VEHICLE 3     object
# CONTRIBUTING FACTOR VEHICLE 4     object
# CONTRIBUTING FACTOR VEHICLE 5     object
# ...

# %%
df.loc[4:7]
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
# 5  04/14/2021      12:47       NaN      NaN        NaN        NaN
# 6  12/14/2021      17:05       NaN      NaN  40.709183 -73.956825
# 7  12/14/2021       8:17     BRONX  10475.0  40.868160 -73.831480
#
#                   LOCATION                ON STREET NAME CROSS STREET NAME  \
# 4  (40.683304, -73.917274)               SARATOGA AVENUE    DECATUR STREET
# 5                      NaN  MAJOR DEEGAN EXPRESSWAY RAMP               NaN
# 6  (40.709183, -73.956825)    BROOKLYN QUEENS EXPRESSWAY               NaN
# 7    (40.86816, -73.83148)                           NaN               NaN
#
#                OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 4                          NaN  ...                            NaN
# 5                          NaN  ...                    Unspecified
# ...

# %%
df[['CRASH DATE', 'CRASH TIME', 'BOROUGH']]
# Out:
#          CRASH DATE CRASH TIME    BOROUGH
# 0        09/11/2021       2:39        NaN
# 1        03/26/2022      11:45        NaN
# 2        06/29/2022       6:55        NaN
# 3        09/11/2021       9:35   BROOKLYN
# 4        12/14/2021       8:13   BROOKLYN
# ...             ...        ...        ...
# 2018958  07/03/2023      18:05        NaN
# 2018959  07/22/2023      21:39      BRONX
# 2018960  07/02/2023      17:55  MANHATTAN
# 2018961  07/22/2023      13:15     QUEENS
# 2018962  07/22/2023       3:00     QUEENS
#
# [2018963 rows x 3 columns]

# %%
df.iloc[1:3, 0:3]
# Out:
#    CRASH DATE CRASH TIME BOROUGH
# 1  03/26/2022      11:45     NaN
# 2  06/29/2022       6:55     NaN

# %%
# Iterating through a list
l = [1, 2, 3, 4, 'Bob', 'Hello world', ['a','b']]
for i in range(0, len(l)):
    print(l[i])
# Out:
# 1
# 2
# 3
# 4
# Bob
# Hello world
# ['a', 'b']

# %% [markdown]
# **Enhanced loop in Java**
#
# ArrayList<Object> x = new ArrayList<Object>();
#
# for(Object a : x){
#
# }

# %%
for item in l:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# Bob
# Hello world
# ['a', 'b']

# %%
i = 0
for idx, row in df.iterrows():
    print(idx, row['LOCATION'])
    i += 1
    if i > 5:
        break
# Out:
# 0 nan
# 1 nan
# 2 nan
# 3 (40.667202, -73.8665)
# 4 (40.683304, -73.917274)
# 5 nan

# %%
df.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# ...

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
# Rename column names to remove spaces
for col in df.columns:
    df.rename({col : col.replace(' ', '_')}, axis=1, inplace=True)

df.head()
# Out:
#    CRASH_DATE CRASH_TIME   BOROUGH ZIP_CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON_STREET_NAME CROSS_STREET_NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF_STREET_NAME  ...  CONTRIBUTING_FACTOR_VEHICLE_2  \
# 0                      NaN  ...                    Unspecified
# ...

# %%
q = "NUMBER_OF_PEDESTRIANS_KILLED >= 5"
df.query(q)
# Out:
#         CRASH_DATE CRASH_TIME    BOROUGH ZIP_CODE   LATITUDE  LONGITUDE  \
# 781939  10/31/2017      15:08  MANHATTAN  10014.0  40.729046  -74.01073
#
#                       LOCATION                    ON_STREET_NAME  \
# 781939  (40.729046, -74.01073)  WEST STREET
#
#           CROSS_STREET_NAME OFF_STREET_NAME  ...  \
# 781939  WEST HOUSTON STREET             NaN  ...
#
#         CONTRIBUTING_FACTOR_VEHICLE_2  CONTRIBUTING_FACTOR_VEHICLE_3  \
# 781939                    Unspecified                    Unspecified
#
#         CONTRIBUTING_FACTOR_VEHICLE_4  CONTRIBUTING_FACTOR_VEHICLE_5  \
# 781939                    Unspecified                    Unspecified
#
#         COLLISION_ID  VEHICLE_TYPE_CODE_1  VEHICLE_TYPE_CODE_2  \
# 781939       3782508             Flat Bed                  Bus
#
#         VEHICLE_TYPE_CODE_3 VEHICLE_TYPE_CODE_4 VEHICLE_TYPE_CODE_5
# 781939                 Bike                Bike                Bike
#
# [1 rows x 29 columns]

# %%
q = "NUMBER_OF_PEDESTRIANS_KILLED >= 3 or NUMBER_OF_CYCLIST_KILLED >=1"
df.query(q)
# Out:
#          CRASH_DATE CRASH_TIME    BOROUGH ZIP_CODE   LATITUDE  LONGITUDE  \
# 1350     07/08/2021      22:03  MANHATTAN  10002.0  40.721474 -73.983830
# 4233     09/11/2021       1:28        NaN      NaN  40.795990 -73.968960
# 15476    06/29/2022      23:54      BRONX  10455.0  40.814266 -73.912964
# 19530    09/25/2021      22:26   BROOKLYN  11207.0  40.657530 -73.897970
# 24991    12/24/2021       9:21  MANHATTAN  10065.0  40.762802 -73.965675
# ...             ...        ...        ...      ...        ...        ...
# 2008000  03/07/2023      18:55        NaN      NaN  40.583690 -73.921570
# 2008002  05/26/2023      21:19   BROOKLYN  11229.0  40.607390 -73.943214
# 2008086  06/04/2023       0:52   BROOKLYN  11211.0  40.715225 -73.944500
# 2009505  06/16/2023      12:39  MANHATTAN  10009.0  40.733210 -73.981064
# 2010145  07/14/2023      17:59        NaN      NaN  40.713924 -73.802120
#
#                         LOCATION       ON_STREET_NAME  CROSS_STREET_NAME  \
# ...

# %%
q = "(NUMBER_OF_PEDESTRIANS_KILLED >= 3 or NUMBER_OF_CYCLIST_KILLED >=1) and BOROUGH == 'BROOKLYN'"
df.query(q)
# Out:
#          CRASH_DATE CRASH_TIME   BOROUGH ZIP_CODE   LATITUDE  LONGITUDE  \
# 19530    09/25/2021      22:26  BROOKLYN  11207.0  40.657530 -73.897970
# 107913   06/27/2021      12:30  BROOKLYN  11236.0  40.646175 -73.920105
# 147589   06/21/2022      22:46  BROOKLYN  11236.0  40.636930 -73.911090
# 152844   08/30/2022      16:25  BROOKLYN  11207.0  40.658577 -73.890630
# 171927   12/25/2020       0:12  BROOKLYN  11232.0  40.662132 -73.999275
# ...             ...        ...       ...      ...        ...        ...
# 1996325  05/01/2023      11:32  BROOKLYN  11238.0  40.686996 -73.956850
# 2006014  04/16/2023      22:50  BROOKLYN  11230.0  40.630096 -73.977060
# 2006609  05/12/2023      16:20  BROOKLYN  11222.0  40.723274 -73.942230
# 2008002  05/26/2023      21:19  BROOKLYN  11229.0  40.607390 -73.943214
# 2008086  06/04/2023       0:52  BROOKLYN  11211.0  40.715225 -73.944500
#
#                         LOCATION                    ON_STREET_NAME  \
# ...

# %%
q = "NUMBER_OF_PEDESTRIANS_KILLED >= 3 or NUMBER_OF_CYCLIST_KILLED >=1"
temp_df = df.query(q)

temp_df.groupby('BOROUGH').agg({'NUMBER_OF_PEDESTRIANS_KILLED': 'sum', 'NUMBER_OF_CYCLIST_KILLED' : 'sum'})
# Out:
#                NUMBER_OF_PEDESTRIANS_KILLED  NUMBER_OF_CYCLIST_KILLED
# BOROUGH
# BRONX                                     0                        24
# BROOKLYN                                  0                        65
# MANHATTAN                                 7                        36
# QUEENS                                    0                        33
# STATEN ISLAND                             0                         3

# %%
df.groupby('BOROUGH').agg({'NUMBER_OF_PEDESTRIANS_KILLED': 'sum', 
                           'NUMBER_OF_CYCLIST_KILLED' : 'sum'})
# Out:
#                NUMBER_OF_PEDESTRIANS_KILLED  NUMBER_OF_CYCLIST_KILLED
# BOROUGH
# BRONX                                   128                        24
# BROOKLYN                                315                        65
# MANHATTAN                               223                        36
# QUEENS                                  267                        33
# STATEN ISLAND                            37                         3

# %%
temp1 = df.groupby('BOROUGH').agg({'NUMBER_OF_PEDESTRIANS_KILLED': 'sum', 
                           'NUMBER_OF_CYCLIST_KILLED' : 'sum'})

# %%
temp1.head()
# Out:
#                NUMBER_OF_PEDESTRIANS_KILLED  NUMBER_OF_CYCLIST_KILLED
# BOROUGH
# BRONX                                   128                        24
# BROOKLYN                                315                        65
# MANHATTAN                               223                        36
# QUEENS                                  267                        33
# STATEN ISLAND                            37                         3

# %%
temp1.reset_index(inplace=True)
temp1.head()
# Out:
#          BOROUGH  NUMBER_OF_PEDESTRIANS_KILLED  NUMBER_OF_CYCLIST_KILLED
# 0          BRONX                           128                        24
# 1       BROOKLYN                           315                        65
# 2      MANHATTAN                           223                        36
# 3         QUEENS                           267                        33
# 4  STATEN ISLAND                            37                         3

# %%
temp1['NUMBER_OF_PEDESTRIANS_KILLED'].hist()
# Out:
# <AxesSubplot:>

# %%
temp1['NUMBER_OF_PEDESTRIANS_KILLED'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.histplot(data=temp1, x='NUMBER_OF_PEDESTRIANS_KILLED', kde=True)
# Out:
# <AxesSubplot:xlabel='NUMBER_OF_PEDESTRIANS_KILLED', ylabel='Count'>

# %%
temp1[['BOROUGH', 'NUMBER_OF_PEDESTRIANS_KILLED']].plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(data=temp1, x='BOROUGH', y='NUMBER_OF_PEDESTRIANS_KILLED')
# Out:
# <AxesSubplot:xlabel='BOROUGH', ylabel='NUMBER_OF_PEDESTRIANS_KILLED'>

# %%
df.head()
# Out:
#    CRASH_DATE CRASH_TIME   BOROUGH ZIP_CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON_STREET_NAME CROSS_STREET_NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF_STREET_NAME  ...  CONTRIBUTING_FACTOR_VEHICLE_2  \
# 0                      NaN  ...                    Unspecified
# ...

# %%
time_df = df.groupby('CRASH_TIME').agg({'NUMBER_OF_PEDESTRIANS_KILLED':'sum'})
time_df.reset_index(inplace=True)
time_df
# Out:
#      CRASH_TIME  NUMBER_OF_PEDESTRIANS_KILLED
# 0          0:00                             0
# 1          0:01                             1
# 2          0:02                             1
# 3          0:03                             1
# 4          0:04                             0
# ...         ...                           ...
# 1435       9:55                             0
# 1436       9:56                             2
# 1437       9:57                             0
# 1438       9:58                             1
# 1439       9:59                             1
#
# [1440 rows x 2 columns]

# %%
time_df.plot.scatter(x='CRASH_TIME', y='NUMBER_OF_PEDESTRIANS_KILLED')
# Out:
# <AxesSubplot:xlabel='CRASH_TIME', ylabel='NUMBER_OF_PEDESTRIANS_KILLED'>

# %%
sns.scatterplot(data=time_df, x='CRASH_TIME', y='NUMBER_OF_PEDESTRIANS_KILLED')
# Out:
# <AxesSubplot:xlabel='CRASH_TIME', ylabel='NUMBER_OF_PEDESTRIANS_KILLED'>

# %%
time_df.head()
# Out:
#   CRASH_TIME  NUMBER_OF_PEDESTRIANS_KILLED
# 0       0:00                             0
# 1       0:01                             1
# 2       0:02                             1
# 3       0:03                             1
# 4       0:04                             0

# %%
time_df['CRASH_TIME_NUM'] = 0
time_df.head()
# Out:
#   CRASH_TIME  NUMBER_OF_PEDESTRIANS_KILLED  CRASH_TIME_NUM
# 0       0:00                             0               0
# 1       0:01                             1               0
# 2       0:02                             1               0
# 3       0:03                             1               0
# 4       0:04                             0               0

# %%
for idx, row in time_df.iterrows():
    crash_time = int(row['CRASH_TIME'].replace(':', ''))
    time_df.at[idx, 'CRASH_TIME_NUM'] = crash_time

# %%
time_df.head()
# Out:
#   CRASH_TIME  NUMBER_OF_PEDESTRIANS_KILLED  CRASH_TIME_NUM
# 0       0:00                             0               0
# 1       0:01                             1               1
# 2       0:02                             1               2
# 3       0:03                             1               3
# 4       0:04                             0               4

# %%
sns.scatterplot(data=time_df, x='CRASH_TIME_NUM', y='NUMBER_OF_PEDESTRIANS_KILLED')
# Out:
# <AxesSubplot:xlabel='CRASH_TIME_NUM', ylabel='NUMBER_OF_PEDESTRIANS_KILLED'>
